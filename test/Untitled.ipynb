# %%
using Test
#include("../src/SimulateDynamics.jl")
#include("../src/GenerateGraphs.jl")
#include("../src/ReduceNetwork.jl")
#include("../src/Partition.jl")
#include("../src/EvaluateError.jl")
include("../src/visualize_landscape.jl")
#include("SimulateDynamicsTest.jl")
#include("GenerateGraphsTest.jl")
#include("ReduceNetworkTest.jl")
include("EvaluateErrorTest.jl")
#include("VisualizeLandscapeTest.jl")
# Out:
# Dict{Integer, Integer} with 50 entries:
#   5  => 1
#   16 => 17
#   20 => 10
#   35 => 2
#   30 => 2
#   19 => 16
#   32 => 2
#   49 => 2
#   6  => 11
#   45 => 2
#   44 => 2
#   9  => 13
#   31 => 2
#   29 => 2
#   46 => 2
#   4  => 14
#   13 => 19
#   21 => 6
#   38 => 2
#   12 => 25
#   24 => 4
#   28 => 2
#   8  => 23
#   17 => 12
#   37 => 2
#   ⋮  => ⋮
# Array{Integer}((50,)) Integer[3, 15, 20, 14, 1, 11, 9, 23, 13, 24  …  2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# ┌ Info: Saved animation to
# │   fn = C:\Users\dlaur\OneDrive\Documents\GitHub\CoarseGrained\test\tmp.gif
# └ @ Plots C:\Users\dlaur\.julia\packages\Plots\1KWPG\src\animation.jl:114
# Plots.AnimatedGif("C:\\Users\\dlaur\\OneDrive\\Documents\\GitHub\\CoarseGrained\\test\\tmp.gif")
# Test Summary:            |
# aggregateTimeSeries_test | No tests
# Test.DefaultTestSet("aggregateTimeSeries_test", Any[], 0, false, false)
